# %%
from src.main import main
from src.reporting import *

res, engine = main()
# Out:
# ==== Mean Reversion (window = 5, trade size = 10) ====
# Total Return: -423.8537
# Sharpe: -0.0073
# Max Drawdown: 13.1157
# Value at Risk (95%): -0.1908
# Expected Shortfall (Conditional 95% VaR): -1.1933
#
# ==== Momentum (window = 3, trade size = 10) ====
# Total Return: 69.5524
# Sharpe: 0.0457
# Max Drawdown: 9.1413
# Value at Risk (95%): -0.9908
# Expected Shortfall (Conditional 95% VaR): -3.1271

# %%
plot_r_ts(res['mr']['cum_r_series'])

# %%
plot_r_ts(res['mom']['cum_r_series'])

# %%
plot_r_dist(res['mr']['r_series'])

# %%
plot_r_dist(res['mom']['r_series'])

# %%
plot_dd(res['mr']['dd_series'])

# %%
plot_dd(res['mom']['dd_series'])
